# %% [markdown]
# ### Exercise 1
#
# Clone the repository shown below
#
# ```python
# url = 'https://github.com/maximoskp/python_colab_packages.git'
# ```
#
# and load a story txt file from the following repository folder:
#
# ```python
# folder = '/content/python_colab_packages/text/short_stories/'
# ```
#
# Create a new folder (e.g. "story_0") that includes subfolders for each line in the story (e.g., "line_0", "line_1", ...) and separate text files for each sentence in each line (e.g., in "story_0\line_0" subfolder there should be sentence files as follows: "sentence_0.txt", "sentence_1.txt", ...).
